# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /drive/notebooks/Text preprocessing
# ['Text preprocessing.ipynb', 'dataset', 'output', 'processing.py', 'requirement.txt']

# %%
import re

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles:")
print(os.listdir())
# Out:
# Current Folder:
# /drive/notebooks/Text preprocessing
#
# Files:
# ['Text preprocessing.ipynb', 'dataset', 'output', 'processing.py', 'requirement.txt']

# %%
import re

with open("dataset/rawdata.txt", "r", encoding="utf-8") as file:
    text = file.read()

print("Original Text:\n")
print(text)

lower_text = text.lower()
upper_text = text.upper()

clean_text = lower_text
clean_text = re.sub(r"[^\w\s]", " ", clean_text)
clean_text = re.sub(r"\d+", "", clean_text)
clean_text = re.sub(r"\s+", " ", clean_text).strip()

print("\nLower Text:\n")
print(lower_text)

print("\nUpper Text:\n")
print(upper_text)

print("\nCleaned Text:\n")
print(clean_text)

with open("output/clean.txt", "w", encoding="utf-8") as file:
    file.write(clean_text)

print("\n✅ Preprocessing Completed Successfully!")
print("✅ clean.txt saved in output folder.")
# Out:
# Original Text:
#
# 👩: Hi! 😊 I’m planning to spend some time outdoors this weekend, and I’m looking for a beautiful park where I can relax with my family. Can you suggest a good place? 🌳
#
# 🤖: Hello! 👋 I’d recommend Semmozhi Poonga. 🌿 It’s one of the most beautiful parks in Chennai, with colorful flowers, green lawns, walking paths, and a peaceful atmosphere. 🌸
#
# 👩: That sounds wonderful! 😍 Could you tell me the park’s opening hours and whether there is an entry fee? ⏰🎟️
#
# 🤖: Of course! 😊 The park is open daily from **6:00 AM to 8:00 PM**. The entry fee is **₹30 for adults** and **₹15 for children**, making it an affordable place to visit. 💵
#
# 👩: Great! 👍 I also enjoy taking photographs of nature. Is photography allowed inside the park? 📷🌼
#
# 🤖: Yes! 📸 Photography is allowed, and there are many beautiful spots where you can capture flowers, trees, fountains, and butterflies. 🌺🦋
#
# 👩: That's amazing! 😄 Are there any facilities like parking, restrooms, or food stalls available for visitors? 🚗🍔
#
# 🤖: Absolutely! 🅿️ The park provides free parking, clean restrooms, drinking water facilities, seating areas, and a few snack stalls where you can buy refreshments. 🍕🥤
#
# 👩: Perfect! 😊 It seems like a wonderful place to spend quality time with my family and enjoy nature together. Thank you for all the information. 🙏❤️
#
# 🤖: You're most welcome! 🤗 I hope you and your family have a fantastic time at the park. 🌳✨ Have a safe trip and enjoy your weekend! 🌸😊
#
# Lower Text:
#
# 👩: hi! 😊 i’m planning to spend some time outdoors this weekend, and i’m looking for a beautiful park where i can relax with my family. can you suggest a good place? 🌳
#
# 🤖: hello! 👋 i’d recommend semmozhi poonga. 🌿 it’s one of the most beautiful parks in chennai, with colorful flowers, green lawns, walking paths, and a peaceful atmosphere. 🌸
#
# 👩: that sounds wonderful! 😍 could you tell me the park’s opening hours and whether there is an entry fee? ⏰🎟️
#
# 🤖: of course! 😊 the park is open daily from **6:00 am to 8:00 pm**. the entry fee is **₹30 for adults** and **₹15 for children**, making it an affordable place to visit. 💵
#
# 👩: great! 👍 i also enjoy taking photographs of nature. is photography allowed inside the park? 📷🌼
#
# 🤖: yes! 📸 photography is allowed, and there are many beautiful spots where you can capture flowers, trees, fountains, and butterflies. 🌺🦋
#
# 👩: that's amazing! 😄 are there any facilities like parking, restrooms, or food stalls available for visitors? 🚗🍔
#
# 🤖: absolutely! 🅿️ the park provides free parking, clean restrooms, drinking water facilities, seating areas, and a few snack stalls where you can buy refreshments. 🍕🥤
