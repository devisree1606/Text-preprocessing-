# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /drive/notebooks/Text preprocessing
# ['Text preprocessing.ipynb', 'dataset', 'output', 'processing.py', 'requirement.txt']

# %%
import re

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles:")
print(os.listdir())
# Out:
# Current Folder:
# /drive/notebooks/Text preprocessing
#
# Files:
# ['Text preprocessing.ipynb', 'dataset', 'output', 'processing.py', 'requirement.txt']
